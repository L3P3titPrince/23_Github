# %%
import queue
import re
from urllib.parse import urlparse
from urllib.parse import urlsplit
from urllib.parse import urljoin
from scrapy import Selector
import csv
import time
from bs4 import BeautifulSoup
import requests
from selenium import webdriver
#this is a faster list
from collections import deque
import os

# %%
new_urls = deque(['http://www.stevens.edu'])

#we use a set for urls to avoid duplicated 
processed_urls = set()

#list of all email address
emails = set()
#print(new_urls)

#process urls from queue on by on until we exhaust this queue
#if we want to get whole result, we should use while but it will take maybe 30min and without end
#if we just want to testify our logical is right, we use for
for _ in range(600):
#while len(new_urls):
    #move next url from the queue to the set of processed urls
    url = new_urls.popleft()
    #print("I got new url:",url)
    #resotre the current url to already done list
    processed_urls.add(url)
    #print("URL has benn processed:",processed_urls)
    #extract base url and path to resolve relative links
    #schema="https", netloc='www.stevens.edu', path='/school-business/faculty', query='', fragment=''
    parts = urlsplit(url)
    #print("After urlspli():",parts)
    base_url = "{0.scheme}://{0.netloc}".format(parts)
    #print("Base url is :", base_url)
    path = url[:url.rfind('/')+1] if '/' in parts.path else url
    #print("path is: ", path)
    #get url's content, if requests error, we esccap and proced next
    url_str = str(url)
    url_str = url_str.replace("https://","")
    url_str = url_str.replace("http://","")
    url_str = url_str.replace("?","")
    url_str = url_str.replace("\\","")
    url_str = url_str.replace("*","")
    url_str = url_str.replace("<","")
    url_str = url_str.replace(">","")
    url_str = url_str.replace(":","")
    url_str = url_str.replace("\"","")
    url_join = ('/root/'+ url_str)
    #print(url_str, url_join)
    os.makedirs(url_str, exist_ok=True)
    print("Processing %s" % url)
    #driver = webdriver.Chrome()
    #driver.get(url)
    try:
        response = requests.get(url)
    except requests.exceptions.ConnectionError:
        #ignore pages with errors
        continue
    #print(response.status_code, response.url)
    #When we got web content, we find all email in it and add it to list.
    soup = BeautifulSoup(response.text)
    #email_addresses += re.findall("\S+@stevens.edu", soup.get_text())
    new_emails = set(re.findall(r"[a-z0-9\.\-+_]+@stevens.edu", soup.get_text(), re.I))

    print("new_emails are:",new_emails)
    emails.update(new_emails)
    print("we success update emails into emails",emails)
    #we find url in this webssit and add it to queue
    soup = BeautifulSoup(response.text)
    #find and process all tha anchors in this html
    for anchor in soup.find_all("a"):
        #extract link url from the anchor
        link=anchor.attrs["href"] if "href" in anchor.attrs else ''
        #link = anchor.get("href") if "href" in anchor.attrs else ''
        #link=anchor.attrs["href"] if "href" in anchor.attrs else ''
        #print("any href link:",link)
        #resolve relative links
        #with open(file_path, 'w+',encoding='utf-8-sig',newline='') as csvfile:
        #writer = csv.writer(csvfile)
        if link.startswith('/'):
            link = base_url +link
        elif not link.startswith('http'):
            link = path + link
            # add the new url to the queue if it was not enqueued nor processed yet
        if not link in new_urls and not link in processed_urls and 'stevens' in link:
            new_urls.append(link)
            
#print("we get new link:",new_urls)
file_path='20_Assignment 03 Email_list.csv' 
with open("email.txt", 'w+') as csvfile:
    for i in emails:
        csvfile.write(i + "\n")
#print(emails)
# Out:
# Processing http://www.stevens.edu
# new_emails are: set()
# we success update emails into emails set()
# Processing http://www.stevens.edu#page
# new_emails are: set()
# we success update emails into emails set()
# Processing http://www.stevens.edu/
# new_emails are: set()
# we success update emails into emails set()
# Processing http://www.stevens.edu/admissions/undergraduate-admissions/how-ap
stevens.edu'}
# we success update emails into emails {'admissions@stevens.edu', 'graduate@stevens.edu'}
# Processing https://gradadmissions.stevens.edu/account/register?r=https%3a%2f%2fgradadmissions.stevens.edu%2fapply%2f
# new_emails are: {'graduate@stevens.edu'}
# we success update emails into emails {'admissions@stevens.edu', 'graduate@stevens.edu'}
# Processing https://gradadmissions.stevens.edu/apply/mailto:graduate@stevens.edu
# new_emails are: {'graduate@stevens.edu'}
# we success update emails into emails {'admissions@stevens.edu', 'graduate@stevens.edu'}
# Processing https://www.instagram.com/stevensgraduate/?hl=en
# new_emails are: set()
# we success update emails into emails {'admissions@stevens.edu', 'graduate@stevens.edu'}
# Processing https://www.linkedin.com/showcase/stevens-graduate-admissions/
# new_emails are: set()
# we success update emails into emails {'admissions@stevens.edu', 'graduate@stevens.edu'}
# Processing https://www.stevens.edu/privacypolicy
# new_emails are: set()
# we success update emails into emails {'admissions@stevens.edu', 'graduate@stevens.edu'}
# Processing http://www.stevenscampusstore.com/
# new_emails are: set()
# we success update emails into emails {'admissions@stevens.edu', 'graduate@stevens.edu'}
# Processing https://www.stevens.edu/events
# new_emails are: set()
# we success update emails into emails {'admissions@stevens.edu', 'graduate@stevens.edu'}
# Processing https://www.stevens.edu/directory/office-human-resources/employment-opportunities
# new_emails are: set()
# we success update emails into emails {'admissions@stevens.edu', 'graduate@stevens.edu'}
# Processing https://gradadmissions.stevens.edu/apply/tel:+12012165000
# new_emails are: {'graduate@stevens.edu'}
# we success update emails into emails {'admissions@stevens.edu', 'graduate@stevens.edu'}
# Processing https://connect.stevens.edu/directorylogin
# new_emails are: set()
# we success update emails into emails {'admissions@stevens.edu', 'graduate@stevens.edu'}
# Processing http://www.stevens.edu/#
# new_emails are: set()
# we success update emails into emails {'admissions@stevens.edu', 'graduate@stevens.edu'}
# Processing https://connect.stevens.edu/rwd/donation-form
# new_emails are: set()
# we success update emails into emails {'admissions@stevens.edu', 'graduate@stevens.edu'}
# Processing https://connect.stevens.edu/rwd/directory-search
# new_emails are: set()
# we success update emails into emails {'admissions@stevens.edu', 'graduate@stevens.edu'}
# Processing https://connect.stevens.edu/rwd/event-calendar
# new_emails are: set()
# we success update emails into emails {'admissions@stevens.edu', 'graduate@stevens.edu'}
# Processing https://connect.stevens.edu/rwd/event-registration-form
# new_emails are: set()
# we success update emails into emails {'admissions@stevens.edu', 'graduate@stevens.edu'}
# Processing https://connect.stevens.edu/rwd/event-registration-form-v2
# new_emails are: set()
# we success update emails into emails {'admissions@stevens.edu', 'graduate@stevens.edu'}
# Processing https://connect.stevens.edu/rwd/rwd-transaction-manager
# new_emails are: set()
# we success update emails into emails {'admissions@stevens.edu', 'graduate@stevens.edu'}
# Processing https://connect.stevens.edu/rwd/alumni-portal
# new_emails are: set()
# we success update emails into emails {'admissions@stevens.edu', 'graduate@stevens.edu'}
# Processing https://connect.stevens.edu/rwd/donor-wall
# new_emails are: set()
# we success update emails into emails {'admissions@stevens.edu', 'graduate@stevens.edu'}
# Processing https://connect.stevens.edu/rwd/honor-roll
# new_emails are: set()
# we success update emails into emails {'admissions@stevens.edu', 'graduate@stevens.edu'}
# Processing https://connect.stevens.edu/rwd/style-guide
# new_emails are: set()
# we success update emails into emails {'admissions@stevens.edu', 'graduate@stevens.edu'}
# Processing https://connect.stevens.edu/giving-pages/fund-search
# new_emails are: set()
# we success update emails into emails {'admissions@stevens.edu', 'graduate@stevens.edu'}
# Processing https://connect.stevens.edu/alumniportal
# new_emails are: set()
# we success update emails into emails {'admissions@stevens.edu', 'graduate@stevens.edu'}
# Processing http://www.stevens.edu/javascript:WebForm_DoPostBackWithOptions(new WebForm_PostBackOptions("PC1869$lnkTarget", "", true, "", "", false, true))
# new_emails are: set()
# we success update emails into emails {'admissions@stevens.edu', 'graduate@stevens.edu'}
# Processing http://www.stevens.edu/javascript:DonationCSCHelp()
# new_emails are: set()
# we success update emails into emails {'admissions@stevens.edu', 'graduate@stevens.edu'}
# Processing https://www.stevens.edu/emergency
# new_emails are: set()
# we success update emails into emails {'admissions@stevens.edu', 'graduate@stevens.edu'}
# Processing https://stevens.edu/makeagift
# new_emails are: set()
# we success update emails into emails {'admissions@stevens.edu', 'graduate@stevens.edu'}
# Processing http://www.stevens.edu/tel:+12012165000
# new_emails are: set()
# we success update emails into emails {'admissions@stevens.edu', 'graduate@stevens.edu'}
# Processing http://www.stevens.edu/#facebook
# new_emails are: set()
# we success update emails into emails {'admissions@stevens.edu', 'graduate@stevens.edu'}
# Processing http://www.stevens.edu/#twitter
# new_emails are: set()
# we success update emails into emails {'admissions@stevens.edu', 'graduate@stevens.edu'}
# Processing http://www.stevens.edu/#instagram
# new_emails are: set()
# we success update emails into emails {'admissions@stevens.edu', 'graduate@stevens.edu'}
# Processing http://www.stevens.edu/#youtube
# new_emails are: set()
# we success update emails into emails {'admissions@stevens.edu', 'graduate@stevens.edu'}
# Processing http://www.stevens.edu/#linkedin
# new_emails are: set()
# we success update emails into emails {'admissions@stevens.edu', 'graduate@stevens.edu'}
# Processing http://www.stevens.edu/#social-media-hub
# new_emails are: set()
# we success update emails into emails {'admissions@stevens.edu', 'graduate@stevens.edu'}
# Processing http://www.stevens.edu/directory/development-and-alumni-engagement
# new_emails are: set()
# we success update emails into emails {'admissions@stevens.edu', 'graduate@stevens.edu'}
# Processing http://www.stevens.edu/directory/development-and-alumni-engagement/give-stevens
# new_emails are: set()
# we success update emails into emails {'admissions@stevens.edu', 'graduate@stevens.edu'}
# Processing http://www.stevens.edu/directory/development-and-alumni-engagement/give-stevens/ways-give
# new_emails are: set()
# we success update emails into emails {'admissions@stevens.edu', 'graduate@stevens.edu'}
# Processing http://www.stevens.edu/directory/development-and-alumni-engagement/give-stevens/make-impact
# new_emails are: set()
# we success update emails into emails {'admissions@stevens.edu', 'graduate@stevens.edu'}
# Processing http://www.stevens.edu/directory/development-and-alumni-engagement/alumni-events
# new_emails are: set()
# we success update emails into emails {'admissions@stevens.edu', 'graduate@stevens.edu'}
# Processing http://www.stevens.edu/directory/development-and-alumni-engagement/stevens-alumni-association
# new_emails are: set()
# we success update emails into emails {'admissions@stevens.edu', 'graduate@stevens.edu'}
# Processing http://www.stevens.edu/directory/development-and-alumni-engagement/stay-informed
# new_emails are: set()
# we success update emails into emails {'admissions@stevens.edu', 'graduate@stevens.edu'}
# Processing http://www.stevens.edu/directory/development-and-alumni-engagement/get-involved
# new_emails are: set()
# we success update emails into emails {'admissions@stevens.edu', 'graduate@stevens.edu'}
# Processing http://www.stevens.edu/directory/development-and-alumni-engagement/scholarships
# new_emails are: set()
# we success update emails into emails {'admissions@stevens.edu', 'graduate@stevens.edu'}
# Processing http://www.stevens.edu/directory/development-and-alumni-engagement/donor-recognition
# new_emails are: set()
# we success update emails into emails {'admissions@stevens.edu', 'graduate@stevens.edu'}
# Processing http://www.stevens.edu/directory/development-and-alumni-engagement/awards
# new_emails are: set()
# we success update emails into emails {'admissions@stevens.edu', 'graduate@stevens.edu'}
# Processing http://www.stevens.edu/directory/development-and-alumni-engagement/corporate-and-foundation-relations
# new_emails are: set()
# we success update emails into emails {'admissions@stevens.edu', 'graduate@stevens.edu'}
# Processing https://connect.stevens.edu/makeagift/stevens-greatest-needs
# new_emails are: set()
# we success update emails into emails {'admissions@stevens.edu', 'graduate@stevens.edu'}
# Processing https://connect.stevens.edu/makeagift/scholarships
# new_emails are: set()
# we success update emails into emails {'admissions@stevens.edu', 'graduate@stevens.edu'}
# Processing https://connect.stevens.edu/makeagift/undergraduate-class-giving
# new_emails are: set()
# we success update emails into emails {'admissions@stevens.edu', 'graduate@stevens.edu'}
# Processing https://connect.stevens.edu/makeagift/academics-and-research
# new_emails are: set()
# we success update emails into emails {'admissions@stevens.edu', 'graduate@stevens.edu'}
# Processing https://connect.stevens.edu/makeagift/stevens-athletics
# new_emails are: set()
# we success update emails into emails {'admissions@stevens.edu', 'graduate@stevens.edu'}
# Processing https://connect.stevens.edu/makeagift/campus-life
# new_emails are: set()
# we success update emails into emails {'admissions@stevens.edu', 'graduate@stevens.edu'}
# Processing https://connect.stevens.edu/power/make-a-gift
# new_emails are: set()
# we success update emails into emails {'admissions@stevens.edu', 'graduate@stevens.edu'}
# Processing http://power.stevens.edu/why-give
# new_emails are: set()
# we success update emails into emails {'admissions@stevens.edu', 'graduate@stevens.edu'}
# Processing http://power.stevens.edu/why-give/student-success
# new_emails are: set()
# we success update emails into emails {'admissions@stevens.edu', 'graduate@stevens.edu'}
# Processing http://power.stevens.edu/why-give/faculty-excellence
# new_emails are: set()
# we success update emails into emails {'admissions@stevens.edu', 'graduate@stevens.edu'}
# Processing http://power.stevens.edu/why-give/vibrant-campus
# new_emails are: set()
# we success update emails into emails {'admissions@stevens.edu', 'graduate@stevens.edu'}
# Processing http://power.stevens.edu/why-give/impact-stories
# new_emails are: set()
# we success update emails into emails {'admissions@stevens.edu', 'graduate@stevens.edu'}
# Processing http://power.stevens.edu/ways-give
# new_emails are: set()
# we success update emails into emails {'admissions@stevens.edu', 'graduate@stevens.edu'}
# Processing http://connect.stevens.edu/makeagift
# new_emails are: set()
# we success update emails into emails {'admissions@stevens.edu', 'graduate@stevens.edu'}
# Processing http://power.stevens.edu/faces-philanthropy
# new_emails are: set()
# we success update emails into emails {'admissions@stevens.edu', 'graduate@stevens.edu'}
# Processing http://power.stevens.edu/faces-philanthropy/donor-profiles
# new_emails are: set()
# we success update emails into emails {'admissions@stevens.edu', 'graduate@stevens.edu'}
# Processing https://connect.stevens.edu/power/honor-roll
# new_emails are: set()
# we success update emails into emails {'admissions@stevens.edu', 'graduate@stevens.edu'}
# Processing http://power.stevens.edu/about-campaign
# new_emails are: set()
# we success update emails into emails {'admissions@stevens.edu', 'graduate@stevens.edu'}
# Processing http://power.stevens.edu/about-campaign/presidents-message
# new_emails are: set()
# we success update emails into emails {'admissions@stevens.edu', 'graduate@stevens.edu'}
# Processing http://power.stevens.edu/about-campaign/campaign-priorities
# new_emails are: set()
# we success update emails into emails {'admissions@stevens.edu', 'graduate@stevens.edu'}
# Processing http://stevens.edu/news
# new_emails are: set()
# we success update emails into emails {'admissions@stevens.edu', 'graduate@stevens.edu'}
# Processing http://power.stevens.edu/get-involved
# new_emails are: set()
# we success update emails into emails {'admissions@stevens.edu', 'graduate@stevens.edu'}
# Processing http://stevens.edu/events
# new_emails are: set()
# we success update emails into emails {'admissions@stevens.edu', 'graduate@stevens.edu'}
# Processing https://power.stevens.edu/why-give
# new_emails are: set()
# we success update emails into emails {'admissions@stevens.edu', 'graduate@stevens.edu'}
# Processing http://power.stevens.edujavascript:void(1);
# ---------------------------------------------------------------------------
# LocationParseError                        Traceback (most recent call last)
# d:\ProgramData\Anaconda3\lib\site-packages\requests\models.py in prepare_url(self, url, params)
#     378         try:
# --> 379             scheme, auth, host, port, path, query, fragment = parse_url(url)
#     380         except LocationParseError as e:
#
# d:\ProgramData\Anaconda3\lib\site-packages\urllib3\util\url.py in parse_url(url)
#     198             if not port.isdigit():
# --> 199                 raise LocationParseError(url)
#     200             try:
#
# LocationParseError: Failed to parse: power.stevens.edujavascript:void(1);
#
# During handling of the above exception, another exception occurred:
#
# InvalidURL                                Traceback (most recent call last)
# <ipython-input-7-3777b604d220> in <module>
#      45     #driver.get(url)
#      46     try:
# ---> 47         response = requests.get(url)
#      48     except requests.exceptions.ConnectionError:
#      49         #ignore pages with errors
#
# d:\ProgramData\Anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# d:\ProgramData\Anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# d:\ProgramData\Anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     517             hooks=hooks,
#     518         )
# --> 519         prep = self.prepare_request(req)
#     520
#     521         proxies = proxies or {}
#
# d:\ProgramData\Anaconda3\lib\site-packages\requests\sessions.py in prepare_request(self, request)
#     460             auth=merge_setting(auth, self.auth),
#     461             cookies=merged_cookies,
# --> 462             hooks=merge_hooks(request.hooks, self.hooks),
#     463         )
#     464         return p
#
# d:\ProgramData\Anaconda3\lib\site-packages\requests\models.py in prepare(self, method, url, headers, files, data, params, auth, cookies, hooks, json)
#     311
#     312         self.prepare_method(method)
# --> 313         self.prepare_url(url, params)
#     314         self.prepare_headers(headers)
#     315         self.prepare_cookies(cookies)
#
# d:\ProgramData\Anaconda3\lib\site-packages\requests\models.py in prepare_url(self, url, params)
#     379             scheme, auth, host, port, path, query, fragment = parse_url(url)
#     380         except LocationParseError as e:
# --> 381             raise InvalidURL(*e.args)
#     382
#     383         if not scheme:
#
# InvalidURL: Failed to parse: power.stevens.edujavascript:void(1);
