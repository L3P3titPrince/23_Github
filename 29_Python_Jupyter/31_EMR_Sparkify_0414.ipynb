# %%
from IPython.display import Image
from IPython.display import SVG

# %% [markdown]
# # <a id="1.Summary">1.Summary</a>

# %% [markdown]
# This data is coming for music company Sparkify which contain churn customer. I will contain all step from construction AWS service to final the result

# %% [markdown]
# - data sourece is “https://udacity-dsnd.s3.amazonaws.com/sparkify/sparkify_event_data.json”
# - https://bucket-emr-15.s3.amazonaws.com/sparkify_event_data.json

# %% [markdown]
# # <a id="2.Table_of_Contents">2.Table of Contents</a>
# <a href="#1.Summary">Click this Link back to Top</a>

# %% [markdown]
# <ol>
#     <li><a href="#1.Summary">Summary</a></li>
#     <li><a href="#2.Table_of_Contents">Table of Contents</a>
#     <li><a href="#3.Implement_EMR">Implement EMR</a></li>
#     <ul>
#         <li><a href="#3.1_Create_Key_Pair">3.1 Create Key Pair</a></li>
#         <li><a href="#3.2 PrePare S3 Storage">3.2 PrePare S3 Storage</a></li>
#         <li><a href="#3.3 EDA">3.3 EDA</a></li>
#         <li><a href="#3.4 Preprocess">3.4 Preprocess</a></li>
#         <li><a href="#3.5 Merge Data">3.5 Merge Data</a></li>
#     </ul>
#     </li>
#     <li><a href="#4.PySpark">PySpark</a>
#     <ul>
#         <li><a href="#4.1_Install_Libraries">4.1 Install Libraries</a></li>
#         <li><a href="#4.2 Hyperparameter">4.2 Hyperparameter</a></li>
#         <li><a href="#4.3_Import_data">4.3 Import Data</a></li>
#     </ul>
#     </li>
#     <li><del><a href="#5.Classify">Classify</a></del></li>
#     <li><del><a href="#6.Models">Models</del></a>
#     <ul>
#         <li><a href="#6.1 Model1">6.1 Model1</a></li>
#         <li><a href="#6.2 Model2">6.2 Model2</a></li>
#     </ul>
#     </li>
#     <li><a href="#7.Main_Function">Main Function</a></li>
#     <li><a href="#8.Test_Code">Test Code</a></li>
# </ol>

# %% [markdown]
# <br>

# %% [markdown]
# <br>

# %% [markdown]
# <br>

# %% [markdown]
# # <a id="3.Implement_EMR">3.Implement EMR</a>
# <a href="#1.Summary">Click this Link back to Top</a>

# %% [markdown]
# <ol>
#     <li>Create key pairt</li>
# </ol>

# %% [markdown]
# ## <a id="3.1_Create_Key_Pair">3.1 Create Key Pair</a>
# <a href="#1.Summary">Click this Link back to Top</a>

# %% [markdown]
# You can use EC2 to build a key pair. We omit the details here.

# %% [markdown]
# <br>

# %% [markdown]
# ## <a id="3.2 PrePare S3 Storage">3.2 PrePare S3 Storage</a>
# <a href="#1.Summary">Click this Link back to Top</a>

# %% [markdown]
# <b>Here is the network structure of this project</b>

# %%
SVG("04_images/11_flowchart.svg")

# %% [markdown]
# <b>Create a S3 bucket to contain your dataset and log of EMR. Create a empty sub floder for log file from EMR Cluster</b>

# %%
Image('04_images/008.png')

# %% [markdown]
# <br>

# %% [markdown]
# ## <a id="3.3 Create Notebook Cluster">3.3 Create Notebook Cluster</a>
# <a href="#1.Summary">Click this Link back to Top</a>

# %% [markdown]
# We can two way running pyspark program on EMR.
# <ol>
#     <li>Create a master with two task node and using key pair access master node, running *.py on master node</li>
#     <li>Create a master with two task node and create a empty notebook to connect existing EMR Cluster</li>
#     <li>Create a seperate NotebookCluster only have one master node to running Jupyter. When you want to running large ammount calcuateiong task, create a new caculation node with various CPU configration</li>
# </ol>
# Because writing on Notebook is easier to read and debug. So we recoommanded to use seperate stand alone EMR Notebook Culster (Thrid Optiion)

# %% [markdown]
# <b>Click Create Cluster</b>

# %%
Image('04_images/003.png')

# %% [markdown]
# <b>I highly recommeand to use "advanced options" to create Notebook Cluster</b>

# %%
Image('04_images/004.png')

# %% [markdown]
# <b>Today is April 10th. EMR system is updating very fast. For now, I recommend using "emr-5.xx" version as our notebook cluster. This version may restrict your CPU selection but more stable. In this example, I will use "emr-5.30.1". If you want to use "emr-5.33.0 or emr-6.xx", you need to select "JupyterEnterpriseGateway 2.1.0". Remember to check all Spark and Livy</b>

# %%
Image('04_images/005.png')

# %% [markdown]
# <b>In this step, you need remain Network in defalut VPC but chagne EC2 Subnet to 1a (some instantce not support on 1e. If you encounter EC2 instance not compatiably, you can check this url for help https://docs.aws.amazon.com/emr/latest/ManagementGuide/emr-INSTANCE_TYPE_NOT_SUPPORTED-error.html </b>

# %%
Image('04_images/006.png')

# %% [markdown]
# <b>As we only build a single node Notebook cluster, we don't need Core and Task, Delete Task and assign ZERO to number of Core instance. And Click Next</b>

# %%
Image('04_images/007.png')

# %% [markdown]
# <b>Rename you Cluster to denote that this is your Notebook single node cluster. Remember to redirect log location to S3 bucket that we created before. After that you can click Next</b>

# %%
Image('04_images/009.png')

# %% [markdown]
# <b>In Step 4, We need to change EC2 key pair to the key pair we created in the begining. EMR actually create cluster on EC2, EMR can also create cluster on EMK, but default server is EC2. So basically, we can use SSH + key pair to access any </b>

# %%
Image('04_images/010.png')

# %% [markdown]
# <b> After Clik create cluster, it will take a few minutes to complete establish process. You need to remember that AWS will start to charge when the status swith from <code>Starting</code> to <code>Waiting</code>. Yes, even <code>Waiting</code> status cost money. Make sure to turn it off when you don't want to use it</b>

# %%
Image('04_images/011.png')

# %% [markdown]
# <br>

# %% [markdown]
# <br>

# %% [markdown]
# <br>

# %% [markdown]
# ## <a id="3.4 Create Jupyter Notebook">3.4 Create Jupyter Notebook</a>
# <a href="#1.Summary">Click this Link back to Top</a>

# %% [markdown]
# <b>During the waiting time, we can create a empty Jupyter notebook</b>

# %%
Image('04_images/012.png')

# %% [markdown]
# <b>Remember to chagne Notebook location, and choose an existing cluster</b>

# %%
Image('04_images/013.png')

# %% [markdown]
# <b>You can change your cluster anytime. Most of scanario is going like this one. When you complete Spark, you should terminate a cluster to avoid extra cost and you can clone a new cluster, then change Notebook to that new cluster</b>

# %%
Image('04_images/014.png')

# %% [markdown]
# <b>First click change, and then choose a <code>Waiting</code> cluster</b>

# %%
Image('04_images/015.png')

# %% [markdown]
# <br>

# %% [markdown]
# <br>

# %% [markdown]
# <br>

# %% [markdown]
# ## <a id="3.5 EMR Cluster">3.5 EMR Cluster</a>
# <a href="#1.Summary">Click this Link back to Top</a>

# %% [markdown]
# <ol>
#     <li>Single Notebook Cluster is only for education, experienment and non-calcuation notebook. If you want really running a full Hadoop or Spark application, you need build a cluster with master, core and task nodes.</li>
#     <li>Before you start choose your instance combination, you need to check your EC2 instance limit <code>https://console.aws.amazon.com/servicequotas/</code></li>
#     <li>The action can increase limitation is in this URL <code>https://aws.amazon.com/cn/premiumsupport/knowledge-center/ec2-instance-limit/</code></li>
# </ol>

# %%
Image('04_images/017.png')

# %% [markdown]
# <b>This is a typical new user limitation dashboard. AWS upper bound for Standard (A,C,D,M) is 1125vCPU, but this account only have 32. Other X,F,G should have 128vCPU limit, but this account have 0.</b>

# %%
Image('04_images/018.png')

# %% [markdown]
# <b>So basic your vCPU limit, you should calcuate your EMR Cluster structrue. For me, I assign a m5.2xlarge ( 8 vCPU, 32GB ) as Master node  + two m5.xlarge ( 4vCPU, 16G ) as Core node. + two m5.xlarge ( 4vCPU, 16GB ) as Task nodes. This Cluster construction have improvement space<b>

# %%
Image('04_images/019.png')

# %% [markdown]
# ## <a id="3.6 Terminate Cluster and Check Bill">3.6 Terminate Cluster and Check Bill</a>
# <a href="#1.Summary">Click this Link back to Top</a>

# %%
Image('04_images/001_emr-workflow.png')

# %% [markdown]
# <br>

# %% [markdown]
# <br>

# %% [markdown]
# <br>

# %% [markdown]
# # <a id="4.PySpark">4.PySpark</a>
# <a href="#1.Summary">Click this Link back to Top</a>

# %% [markdown]
# Version Control:
# <ul>
#     <li>EMR-5.30.1</li>
# </ul>

# %% [markdown]
# ## <a id="4.1_Install_Libraries">4.1 Install Libraries</a>
# <a href="#1.Summary">Click this Link back to Top</a>

# %% [markdown]
# <ol>
#     <li>install and import libraries, it seems that we should install these packages every time before we run our Online EMR code</li>
#     <li>session it self is depend on YARN, which means every time i start a new notebook, it will start a new session from basic virtal env</li>
# </ol>

# %%
sc.install_pypi_package("pandas")
sc.install_pypi_package("matplotlib", "https://pypi.org/simple")
sc.install_pypi_package("scikit-learn")
sc.install_pypi_package("s3fs")
sc.list_packages()
# Out:
# VBox()
# Starting Spark application
# <table>
# <tr><th>ID</th><th>YARN Application ID</th><th>Kind</th><th>State</th><th>Spark UI</th><th>Driver log</th><th>Current session?</th></tr><tr><td>1</td><td>application_1618419402271_0002</td><td>pyspark</td><td>idle</td><td><a target="_blank" href="http://ip-172-31-44-214.ec2.internal:20888/proxy/application_1618419402271_0002/">Link</a></td><td><a target="_blank" href="http://ip-172-31-43-44.ec2.internal:8042/node/containerlogs/container_1618419402271_0002_01_000001/livy">Link</a></td><td>✔</td></tr></table>
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# SparkSession available as 'spark'.
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# ...
#   Using cached https://files.pythonhosted.org/packages/51/51/48f3fc47c4e2144da2806dfb6629c4dd1fa3d5a143f9652b141e979a8ca9/pandas-1.2.4-cp37-cp37m-manylinux1_x86_64.whl
# ...

# %% [markdown]
# <br>

# %% [markdown]
# ## <a id="4.2 Hyperparameter">4.2 Hyperparameter</a>
# <a href="#1.Summary">Click this Link back to Top</a>

# %%
class HyperParamters(object):
    """
    
    """
    
    def __init__(self):
        """:arg


        """
        self.TEST = 1
        
        # these are data S3 URI address
        self.FULL_ADDRESS = "s3://03-test-bucket/021_sparkify_event_data.json"
        self.MEDIUM_ADDRESS = "s3://03-test-bucket/medium-sparkify-event-data.json"
        
        self.CLUSTER = "Current, We use 1 Master, 2 Cores, and 2 Tasks spend {} time"
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
import numpy as np
import pandas as pd
import time
#this package support pandas to read files on S3 storage
# import s3fs

import matplotlib.pyplot as plt

from pyspark.sql import SparkSession, Window
from pyspark.sql import functions as F
from pyspark.sql.functions import udf, lit, struct, countDistinct, collect_list, avg, count, col
from pyspark.sql.functions import sum as Fsum
from pyspark.sql.types import ArrayType, BooleanType, LongType, FloatType, IntegerType
from pyspark.ml.feature import VectorAssembler, Normalizer, StandardScaler
from pyspark.ml.classification import LogisticRegression, RandomForestClassifier, GBTClassifier
from pyspark.ml.evaluation import MulticlassClassificationEvaluator, BinaryClassificationEvaluator
from pyspark.ml import Pipeline
from pyspark.ml.tuning import CrossValidator, ParamGridBuilder

from sklearn.metrics import roc_curve
from sklearn.metrics import precision_recall_curve
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %% [markdown]
# ## <a id="4.3_Import_data">4.3 Import Data</a>
# <a href="#1.Summary">Click this Link back to Top</a>

# %%
from pyspark.sql import SparkSession, Window
import time

class ImportData(HyperParamters):
    """
    Contain two method: import data and convert time


    """
    def __init__(self):
        # inhereit from HyperParameter
        HyperParamters.__init__(self)

    
    def import_data(self):
        """
        
        Return:
        -------
        
        """
        # create a 
        spark = SparkSession \
                .builder \
                .master("local") \
                .appName("Sparkify_ML") \
                .getOrCreate()
        
        start = time.time()
        # the type of this df is 'pyspark.sql.dataframe.DataFrame'
        df = spark.read.json(self.MEDIUM_ADDRESS)
        # print the first five rows
        print("These are the first FIVE rous data.", df.show(5))
        # another way to present first 5 rows
        # df.limit(5).toPandas()
        # print out the columns names of this DataFrame
        print("These are the colunm names of this ", df.columns)
        # df.shape
        print("The shape of this data is", (df.count(), len(df.columns)))
        
        end = time.time()
        print(self.CLUSTER.format(end-start))
        
        return df
        
        
    def clean_data(self, df):
        """
        """
        # we think these columns are irrelvant to our anlysis 
        # spark drop don't need list, string is enough
        # df = df.drop(*['artist', 'song', 'firstName', 'lastName', 'id_copy'])
        df = df.drop('artist', 'song', 'firstName', 'lastName', 'id_copy')
        print("The shape of this data is", (df.count(), len(df.columns)))
        # drop potential Nan values in ['userID', sessionID] columns
        df = df.dropna(how = 'any', subset = ['userId', 'sessionId'])
        print("The shape of this data is", (df.count(), len(df.columns)))
        # this is another way to eliminate Nan value. dropna() is to elimnate np.nan, this is for null value
        df = df.filter(df['userId']!="").orderBy(['userId', 'ts'], ascending=[True, True])
        print("The shape of this data is", (df.count(), len(df.columns)))
        # withColumn() used to manipulate all rows of target colunm
        # current ['userId'] type is 'str'. You can check by type(df.collect()[0]['userId'])
        print(type(df.collect()[0]['userId']))
        # we chenge is type to Integer
        df = df.withColumn('userId', df['userId'].cast(IntegerType()))
        print(type(df.collect()[0]['userId']))
        
        return df
    
    def identify_churn(self, df):
        """
        We use ['Page'] infomation with "Cancellation Confirmation" to identify 
        """
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
class_import = ImportData()
df_1 = class_import.import_data()
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# +-----------------+---------+---------+------+-------------+--------+---------+-----+--------------------+------+--------+-------------+---------+------------------+------+-------------+--------------------+------+
# |           artist|     auth|firstName|gender|itemInSession|lastName|   length|level|            location|method|    page| registration|sessionId|              song|status|           ts|           userAgent|userId|
# +-----------------+---------+---------+------+-------------+--------+---------+-----+--------------------+------+--------+-------------+---------+------------------+------+-------------+--------------------+------+
# |    Martin Orford|Logged In|   Joseph|     M|           20| Morales|597.55057| free|  Corpus Christi, TX|   PUT|NextSong|1532063507000|      292|     Grand Designs|   200|1538352011000|"Mozilla/5.0 (Mac...|   293|
# ...

# %% [markdown]
# <br>

# %% [markdown]
# <br>

# %% [markdown]
# <br>

# %% [markdown]
# ## <a id="4.3_Import_data">4.3 Import Data</a>
# <a href="#1.Summary">Click this Link back to Top</a>

# %%
# class_import = ImportData()
df_2 = class_import.clean_data(df_1)
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# The shape of this data is (543705, 14)
# The shape of this data is (543705, 14)
# The shape of this data is (528005, 14)
# <class 'str'>
# <class 'int'>

# %%
df_2.select(df_2['page']).show(3)
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# +--------+
# |    page|
# +--------+
# |NextSong|
# |    Home|
# |NextSong|
# +--------+
# only showing top 3 rows

# %%
def define_churn(df):
    """
    The churn rate, also known as the rate of attrition or customer churn, is the rate at which customers stop doing business with an entity.
    According to ['page'] content, which have various status
    +-------------------------+-----------+
    |page                     |sum(userId)|
    +-------------------------+-----------+
    |Downgrade                |175766552  |
    |Save Settings            |31871155   |
    |Error                    |29361154   |
    |Add to Playlist          |760358544  |
    |Help                     |160714361  |
    |Submit Upgrade           |20730766   |
    |Cancel                   |6608554    |
    |Submit Downgrade         |8812187    |
    |Thumbs Down              |377920980  |
    |Home                     |1135429788 |
    |Roll Advert              |477573836  |
    |About                    |59219665   |
    |Upgrade                  |66700838   |
    |Cancellation Confirmation|6608554    |
    |NextSong                 |25527511521|
    |Thumbs Up                |1962135103 |
    |Logout                   |344104894  |
    |Settings                 |177446902  |
    |Add Friend               |493155281  |
    +-------------------------+-----------+
    
    We only use status "Cancellation Confirmation". We believe, 
    """
    # you can use similar groupby function and combine number with "userId"
    df.groupby("page").sum("userId").show(truncate=False)
    # define a fucntion, when imput is 'Cancellation Confirmation', output is 1, else is 0, and 1/0 will be integer type
    cancelation = udf(lambda x:1 if x =="Cancellation Confirmation" else 0, IntegerType())
    # create a column ['chrun'] from processs function on column['page']
    df = df.withColumn("churn", cancelation("page"))
    # check the number of ['churn'] column
    df.groupby("churn").sum('userId').show(truncate=False)
    
    
    return df
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
df_3 = define_churn(df_2)
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# +-------------------------+-----------+
# |page                     |sum(userId)|
# +-------------------------+-----------+
# |Downgrade                |175766552  |
# |Save Settings            |31871155   |
# |Error                    |29361154   |
# |Add to Playlist          |760358544  |
# |Help                     |160714361  |
# |Submit Upgrade           |20730766   |
# |Cancel                   |6608554    |
# |Submit Downgrade         |8812187    |
# |Thumbs Down              |377920980  |
# |Home                     |1135429788 |
# |Roll Advert              |477573836  |
# |About                    |59219665   |
# |Upgrade                  |66700838   |
# |Cancellation Confirmation|6608554    |
# |NextSong                 |25527511521|
# |Thumbs Up                |1962135103 |
# |Logout                   |344104894  |
# ...

# %%
from pyspark.sql.functions import max
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
# unboundedPreceding reprecent infinite rows before current rows
# unboundedFoloowing represent infinite rows after current rows
windows_1 = Window.partitionBy("userId").rangeBetween(Window.unboundedPreceding, Window.unboundedFollowing)
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
df_5 = df_3.withColumn("churn_2", max("churn").over(windows_1))
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
df_5.columns
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# ['auth', 'gender', 'itemInSession', 'length', 'level', 'location', 'method', 'page', 'registration', 'sessionId', 'status', 'ts', 'userAgent', 'userId', 'churn', 'churn_2']

# %%
df_5.groupby("churn_2").max('userId').show(truncate=False)
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# +-------+-----------+
# |churn_2|max(userId)|
# +-------+-----------+
# |1      |300047     |
# |0      |300051     |
# +-------+-----------+

# %%
df_4.columns
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# ['auth', 'gender', 'itemInSession', 'length', 'level', 'location', 'method', 'page', 'registration', 'sessionId', 'status', 'ts', 'userAgent', 'userId', 'churn', 'churn_test']

# %%
df_4.groupby("churn_test").sum('userId').show(truncate=False)
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# +----------+-----------+
# |churn_test|sum(userId)|
# +----------+-----------+
# |1         |4674800234 |
# |0         |27147230401|
# +----------+-----------+

# %%
windows_1
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# ...

# %%
df_4.select("churn_test").show(3)
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# +----------+
# |churn_test|
# +----------+
# |         0|
# |         0|
# |         0|
# +----------+
# only showing top 3 rows

# %%
df_3.groupby("churn").sum('userId').show(truncate=False)
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# +-----+-----------+
# |churn|sum(userId)|
# +-----+-----------+
# |1    |6608554    |
# |0    |31815422081|
# +-----+-----------+

# %%
df_2.groupby('page').sum('userId').show(truncate=False)
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# +-------------------------+-----------+
# |page                     |sum(userId)|
# +-------------------------+-----------+
# |Downgrade                |175766552  |
# |Save Settings            |31871155   |
# |Error                    |29361154   |
# |Add to Playlist          |760358544  |
# |Help                     |160714361  |
# |Submit Upgrade           |20730766   |
# |Cancel                   |6608554    |
# |Submit Downgrade         |8812187    |
# |Thumbs Down              |377920980  |
# |Home                     |1135429788 |
# |Roll Advert              |477573836  |
# |About                    |59219665   |
# |Upgrade                  |66700838   |
# |Cancellation Confirmation|6608554    |
# |NextSong                 |25527511521|
# |Thumbs Up                |1962135103 |
# |Logout                   |344104894  |
# ...

# %%
df_2 = df.drop(*['artist', 'song', 'firstName', 'lastName', 'id_copy'])
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
df_2.select(df_2.userId[0:0])
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# DataFrame[substring(userId, 0, 0): string]

# %%
df_2.select(df_2.columns[1:3])
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# DataFrame[gender: string, itemInSession: bigint]

# %%
type(df_2.collect()[0]['userId'])
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# <class 'str'>

# %%
df_2.filter(df_2['userId']=='').show(5)
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# +----------+------+-------------+------+-----+--------+------+-----+------------+---------+------+-------------+---------+------+
# |      auth|gender|itemInSession|length|level|location|method| page|registration|sessionId|status|           ts|userAgent|userId|
# +----------+------+-------------+------+-----+--------+------+-----+------------+---------+------+-------------+---------+------+
# |Logged Out|  null|          186|  null| paid|    null|   GET| Home|        null|      178|   200|1538352148000|     null|      |
# |Logged Out|  null|          187|  null| paid|    null|   GET| Home|        null|      178|   200|1538352151000|     null|      |
# |Logged Out|  null|          188|  null| paid|    null|   GET| Home|        null|      178|   200|1538352168000|     null|      |
# ...

# %%
df_3 = df.drop('artist', 'song', 'firstName', 'lastName', 'id_copy')
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
df_3.columns
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# ['auth', 'gender', 'itemInSession', 'length', 'level', 'location', 'method', 'page', 'registration', 'sessionId', 'status', 'ts', 'userAgent', 'userId']

# %%
start = time.time()
#clearning the dataset
#drop some irrelevant columns
df = df.drop(*['artist', 'song','firstName','lastName','id_copy'])
#drop some potential NAN values
df = df.dropna(how='any', subset = ['userId','sessionId'])
#filtering out the invalid Ids
df = df.filter(df.userId!='').orderBy(['userId', 'ts'], ascending=[True, True])
#case userID column to integer
df = df.withColumn("userId", df["userId"].cast(IntegerType()))



#defining the chrun
#these are customers landing on the Cancellation Confirmation page
cancelation = udf(lambda x: 1 if x == "Cancellation Confirmation" else 0, IntegerType())  
df = df.withColumn("churn", cancelation("page"))
window = Window.partitionBy("userId").rangeBetween(Window.unboundedPreceding, Window.unboundedFollowing)
df = df.withColumn("churn", Fsum("churn").over(window))

#some new columns were made in this step to make the data exploration easier, the Feature engineering step comes later

#making the level_shift Column
#this column tell us how many times did the customer switched from paid to free service
window_1 = Window.partitionBy().orderBy(['userId', 'ts'])
df = df.withColumn("level_shift", (df.level!=F.lag(df.level).over(window_1)) \
                   | (df.userId!=F.lag(df.userId).over(window_1)))
df = df.fillna({'level_shift':0})
df = df.withColumn("level_shift", F.when(df["level_shift"]==False, 0).otherwise(1))

#making the last_ts column
#this column will help us to select only records that happened in the last 2 weeks of customer activity
#the idea is that customer behavior should be different shortly before the churn happened
#trimming the last three zeros from the UNIT time(miliseconds)
df = df.withColumn("ts", df.ts/1000)
df = df.withColumn("registration", df.registration/1000)
#window_2
window_2 = Window.partitionBy("userId")
#
df = df.withColumn("last_ts", F.max("ts").over(window_2))
#2592000 this approxmiate number of seconds in a week period
df = df.filter(df.last_ts - df.ts < 1300000)

#making the columns:papes_per _seesion, diff_time
#pages_per+session is number of pages perseesion
#diff_time is a number of days since a specific page was visited

window_3 = Window.partitionBy(["userId", "sessionId"])
df = df.withColumn("pages_per_session", F.max("ItemInSession").over(window_3))
#unix to datatime
df = df.withColumn("ts_time", F.to_timestamp(df.ts))
#unix time style to normal datatime
df = df.withColumn("last_ts_time", F.to_timestamp(df.last_ts))

#how many days ago was the page visited
df = df.withColumn('diff_time', F.datediff(df.last_ts_time, df.ts_time))
df = df.orderBy(["userId", "ts"], ascending = [True, True])
#create a temp Table to be used for swl queries
df.createOrReplaceTempView('data');


end = time.time()
print("4 Core and 12 Task Cleaning Data Model take time is ", end-start)
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# 4 Core and 12 Task Cleaning Data Model take time is  0.8517119884490967

# %%
#the column "page" seems to be most informative in the whole datset

df.select('page', 'UserId').groupby('page').agg({'page':'count'}).select('page', 'count(page)').show()
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# +--------------------+-----------+
# |                page|count(page)|
# +--------------------+-----------+
# |              Cancel|       5003|
# |    Submit Downgrade|       2450|
# |         Thumbs Down|      89370|
# |                Home|     425269|
# |           Downgrade|      73782|
# |         Roll Advert|     125746|
# |              Logout|     106746|
# |       Save Settings|      10755|
# |Cancellation Conf...|       5003|
# |               About|      27272|
# | Submit Registration|         98|
# |            Settings|      54420|
# |               Login|      63666|
# |            Register|        208|
# |     Add to Playlist|     221047|
# |          Add Friend|     139143|
# |            NextSong|    7709280|
# |           Thumbs Up|     418797|
# |                Help|      52636|
# |             Upgrade|      15173|
# ...

# %%
df.printSchema();
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# root
#  |-- auth: string (nullable = true)
#  |-- gender: string (nullable = true)
#  |-- itemInSession: long (nullable = true)
#  |-- length: double (nullable = true)
#  |-- level: string (nullable = true)
#  |-- location: string (nullable = true)
#  |-- method: string (nullable = true)
#  |-- page: string (nullable = true)
#  |-- registration: double (nullable = true)
#  |-- sessionId: long (nullable = true)
#  |-- status: long (nullable = true)
#  |-- ts: double (nullable = true)
#  |-- userAgent: string (nullable = true)
#  |-- userId: integer (nullable = true)
#  |-- churn: long (nullable = true)
#  |-- level_shift: integer (nullable = false)
#  |-- last_ts: double (nullable = true)
#  |-- pages_per_session: long (nullable = true)
#  |-- ts_time: timestamp (nullable = true)
#  |-- last_ts_time: timestamp (nullable = true)
# ...

# %%
# Investigation if there are differences between churned and non-churned users

# label             - 0 if non_churned, 1 if churned
# song_count        - avg number of songs played by churned/non_churned users
# error             - avg number of errors occuring 
# friends           - avg number of "friends" on thhe application
# playlist_count    - avg number of visits to the Playlist page
# thumbs_up         - avg number of clicking the 'thumbs up'
# thumbs_down       - avg number of clicking the 'thumbs down'
# downgrade         - avg number of visits to the downgrade page
# count_session_dist- avg number of sessions made
# count_diff_time   - avg number of days (in the last two weeks) in which the user used the app
# pages per session - avg numbers of pages (or any activity or changes) per session
# duration          - avg number of days since the user joined (division with 86400 as a proxy of seconds within a day)
# level_shift       - avg number of level changes (free, paid) per customer
# usage_time        - avg total time spent using the app

start = time.time()
stats = spark.sql(" WITH prep as( \
SELECT userId, \
max(churn)                                                          as label, \
count(case when page = 'NextSong' then userId else null end)        as song_count, \
count(case when page = 'Error' then userId else null end)           as error, \
count(case when page = 'Add Friend' then userId else null end)      as friends, \
count(case when page = 'Add to Playlist' then userId else null end) as playlist_count, \
count(case when page = 'Thumbs Up' then userId else null end)       as thumbs_up, \
count(case when page = 'Thumbs Down' then userId else null end)     as thumbs_down, \
count(case when page = 'Downgrade' then userId else null end)       as downgrade, \
count(distinct sessionId)                                           as count_session_dist, \
count(distinct diff_time)                                           as count_diff_time, \
avg(distinct pages_per_session)                                     as pages_per_session, \
(max(ts) - min(registration))/86400                                 as duration, \
sum(level_shift)                                                    as level_shift, \
sum(length)                                                         as usage_time \
FROM data \
GROUP BY userId) \
SELECT label, \
count(label)             as cnt, \
avg(song_count)          as song_count, \
avg(error)               as error, \
avg(friends)             as friends, \
avg(playlist_count)      as playlist_count, \
avg(thumbs_up)           as thumbs_up, \
avg(thumbs_down)         as thumbs_down, \
avg(downgrade)           as downgrade, \
avg(count_session_dist)  as count_session_dist, \
avg(count_diff_time)     as count_diff_time, \
avg(pages_per_session)   as pages_per_session, \
avg(duration)            as duration, \
avg (level_shift)        as level_shift, \
avg(usage_time)          as usage_time \
FROM prep \
GROUP BY label")

# We can see that for most dimensions/features there are differences between churned and non-churned users
stats.toPandas()

end = time.time()
print('4 Core and 12 Task take {} seconds'.format(end - start))
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# 4 Core and 12 Task take 150.19197535514832 seconds

# %%
stats.show(n=2, truncate=False, vertical=True)
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# -RECORD 0---------------------------------
#  label              | 0
#  cnt                | 17275
#  song_count         | 311.4591027496382
#  error              | 0.38309696092619394
#  friends            | 5.630448625180898
#  playlist_count     | 8.965962373371925
#  thumbs_up          | 17.397510853835023
#  thumbs_down        | 3.4504196816208395
#  downgrade          | 2.8214182344428367
#  count_session_dist | 6.465354558610709
#  count_diff_time    | 4.402257597684515
#  pages_per_session  | 88.69388326056588
#  duration           | 89.08563652583196
#  level_shift        | 2.722026049204052
#  usage_time         | 77847.83898664259
# -RECORD 1---------------------------------
#  label              | 1
#  cnt                | 5003
#  song_count         | 465.4855086947831
#  error              | 0.5628622826304217
#  friends            | 8.370377773336
# ...

# %%
df_5 = stats.toPandas()
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
start=time.time()
# Feature Enigneering

# Based on the previous analysis, all 14 investigated features will be included. 
# Here I am making a Temp Table which holds all the features.
# The temp table will be used as model input
# All data is aggregated per userId


features = spark.sql("SELECT userId, \
max(churn)                                                          as label, \
count(case when page = 'NextSong' then userId else null end)        as song_count, \
count(case when page = 'Error' then userId else null end)           as error, \
count(case when page = 'Add Friend' then userId else null end)      as friends, \
count(case when page = 'Add to Playlist' then userId else null end) as playlist_count, \
count(case when page = 'Thumbs Up' then userId else null end)       as thumbs_up, \
count(case when page = 'Thumbs Down' then userId else null end)     as thumbs_down, \
count(case when page = 'Downgrade' then userId else null end)       as downgrade, \
count(distinct sessionId)                                           as count_session_dist, \
count(distinct diff_time)                                           as count_diff_time, \
round(avg(distinct pages_per_session),0)                                     as pages_per_session, \
round((max(ts) - min(registration))/86400,0)                                as duration, \
round(sum(level_shift),0)                                                  as level_shift, \
round(sum(length),0)                                                         as usage_time \
FROM data \
GROUP BY userId");

features.createOrReplaceTempView('features');
features=features.na.drop() # clean potential NaNs


end = time.time()
c4t12_print(start, end)
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# 4 Core and 12 Tasks take 0.10963582992553711 seconds in thi model

# %%
start=time.time()
features.show(n=2, truncate=False, vertical=True)
end = time.time()
c4t12_print(start, end)
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# -RECORD 0----------------------
#  userId             | 1041322
#  label              | 1
#  song_count         | 765
#  error              | 1
#  friends            | 10
#  playlist_count     | 20
#  thumbs_up          | 31
#  thumbs_down        | 7
#  downgrade          | 10
#  count_session_dist | 7
#  count_diff_time    | 9
#  pages_per_session  | 133.0
#  duration           | 108.0
#  level_shift        | 0
#  usage_time         | 190753.0
# -RECORD 1----------------------
#  userId             | 1226805
#  label              | 0
#  song_count         | 756
#  error              | 2
#  friends            | 11
#  playlist_count     | 28
#  thumbs_up          | 73
#  thumbs_down        | 8
#  downgrade          | 4
#  count_session_dist | 8
#  count_diff_time    | 8
#  pages_per_session  | 117.0
#  duration           | 70.0
#  level_shift        | 2
# ...

# %%
type(features)
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# <class 'pyspark.sql.dataframe.DataFrame'>

# %%
df_6 = features.toPandas()
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
type(df_6)
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# <class 'pandas.core.frame.DataFrame'>

# %%
df_6.columns
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# Index(['userId', 'label', 'song_count', 'error', 'friends', 'playlist_count',
#        'thumbs_up', 'thumbs_down', 'downgrade', 'count_session_dist',
#        'count_diff_time', 'pages_per_session', 'duration', 'level_shift',
#        'usage_time'],
#       dtype='object')

# %%
df_6.shape
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# (22192, 15)

# %%
df_6[df_6['label']==1]
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
#         userId  label  song_count  ...  duration  level_shift  usage_time
# 0      1065787      1         402  ...      25.0            1    100819.0
# 6      1711766      1        1823  ...      87.0            0    452765.0
# 16     1105036      1        1574  ...      65.0            1    393949.0
# 17     1261561      1         405  ...       9.0            2     99607.0
# 36     1702129      1        1427  ...      53.0            2    352510.0
# ...        ...    ...         ...  ...       ...          ...         ...
# 22161  1369625      1          93  ...      71.0            0     23665.0
# 22165  1505317      1         538  ...      60.0            0    132080.0
# 22173  1396828      1         852  ...     251.0            0    213630.0
# 22181  1386738      1          57  ...      71.0            0     14047.0
# ...

# %%
df_6[df_]

# %%
fig, ax = plt.subplots()
ax.barh(group_names, group_data)

# %%
fig, axs = plt.subplots(2, 2, figsize=(5, 5))
axs[0, 0].hist(df_6)
#axs[1, 0].scatter(data[0], data[1])
#axs[0, 1].plot(data[0], data[1])
#axs[1, 1].hist2d(data[0], data[1])

# %% [markdown]
# <br>

# %% [markdown]
# <br>

# %% [markdown]
# <br>

# %% [markdown]
# <br>

# %% [markdown]
# Models

# %%
start = time.time()
# Train Test Split
training, test = features.randomSplit([0.8, 0.2])


# Make VectorAssembler - this is a Pypark specific step
# All input features must be in one column before feeding into the model

assembler = VectorAssembler(inputCols=["userId","song_count","error","friends","playlist_count", \
                                       "thumbs_up","thumbs_down","downgrade", "count_session_dist",\
                                       "count_diff_time","pages_per_session", "duration","level_shift",\
                                       "usage_time"], \
                            outputCol="inputFeatures")



# Normalize Data
scaler = Normalizer(inputCol="inputFeatures", outputCol="features")


# Spark supports most common classification methods (https://spark.apache.org/docs/latest/ml-classification-regression.html)
# I decided for the following three:

lr=LogisticRegression()
gbt = GBTClassifier()
rf= RandomForestClassifier()


# Building pipelines
pipeline1=Pipeline(stages=[assembler, scaler, lr])
pipeline2=Pipeline(stages=[assembler, scaler, gbt])
pipeline3=Pipeline(stages=[assembler, scaler, rf])

end = time.time()
c4t12_print(start, end)
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# 4 Core and 12 Tasks take 0.10284852981567383 seconds in thi model

# %% [markdown]
# <br>

# %% [markdown]
# <br>

# %% [markdown]
# <br>

# %% [markdown]
# Logistic Regression

# %%
start = time.time()
# metric chosen is f1 (we want to catch true positives (churn customers), but
# we do not want to waste money on false positives (investing in retaining non-churn customers, which are loyal anyway)
# Note that Recall might also be justified to use here (if the cost of false positives is low)


paramgrid =ParamGridBuilder()\
.addGrid(lr.regParam, [0.0, 0,1])\
.addGrid(lr.maxIter, [10])\
.build()


evaluator=MulticlassClassificationEvaluator(metricName="f1")
#evaluator=BinaryClassificationEvaluator( metricName="areaUnderROC")

# Crossvalidator (https://spark.apache.org/docs/2.1.3/api/python/_modules/pyspark/ml/tuning.html)

crossval= CrossValidator(estimator=pipeline1,  
                         estimatorParamMaps=paramgrid,
                         evaluator = evaluator , 
                         numFolds=3
                        )

cvModel1=crossval.fit(training) 
evaluator.evaluate(cvModel1.transform(test))
#cvModel1.subModels() 
#cvModel1.avgMetrics

end = time.time()
c4t12_print(start, end)
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# 4 Core and 12 Tasks take 1062.1369140148163 seconds in thi model

# %% [markdown]
# Gradient Boosted Tree Classifier

# %%
# Specify multiple parameters in the paramgrid, in case you have enough processing power 
start = time.time()
paramgrid1 =ParamGridBuilder()\
.build()

evaluator=MulticlassClassificationEvaluator(metricName="f1")

crossval= CrossValidator(estimator=pipeline2,  
                         estimatorParamMaps=paramgrid1,
                         evaluator=evaluator, 
                         numFolds=3
                        )

cvModel2=crossval.fit(training) 
evaluator.evaluate(cvModel2.transform(test))
end = time.time()
c4t12_print(start, end)
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# Exception in thread cell_monitor-18:
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/opt/conda/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.7/site-packages/awseditorssparkmonitoringwidget-1.0-py3.7.egg/awseditorssparkmonitoringwidget/cellmonitor.py", line 178, in cell_monitor
#     job_binned_stages[job_id][stage_id] = all_stages[stage_id]
# KeyError: 2311
# 4 Core and 12 Tasks take 1186.9926142692566 seconds in thi model

# %%
start = time.time()
# Specify multiple parameters in the paramgrid, in case you have enough processing power
paramgrid2 =ParamGridBuilder()\
.build()

evaluator=MulticlassClassificationEvaluator(metricName="f1")
#evaluator=BinaryClassificationEvaluator( metricName="areaUnderROC")

crossval= CrossValidator(estimator=pipeline3,  
                         estimatorParamMaps=paramgrid2,
                         evaluator=evaluator, 
                         numFolds=3
                        )

cvModel3=crossval.fit(training) 
evaluator.evaluate(cvModel3.transform(test))

end = time.time()
c4t12_print(start, end)
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# Exception in thread cell_monitor-20:
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/opt/conda/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.7/site-packages/awseditorssparkmonitoringwidget-1.0-py3.7.egg/awseditorssparkmonitoringwidget/cellmonitor.py", line 178, in cell_monitor
#     job_binned_stages[job_id][stage_id] = all_stages[stage_id]
# KeyError: 6491
# 4 Core and 12 Tasks take 1038.940399646759 seconds in thi model

# %%
start = time.time()
predictions=cvModel1.transform(test)
#predictions.limit(2).toPandas()
end = time.time()
c4t12_print(start, end)
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# 4 Core and 12 Tasks take 0.08550763130187988 seconds in thi model

# %%
predictions.select['probability']
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# 'method' object is not subscriptable
# Traceback (most recent call last):
# TypeError: 'method' object is not subscriptable

# %% [markdown]
# Visualisations

# %%
# Gradient Boosted Tree Classifier seems to be the winner model, let us plot its Precision-Recall Curve
 
start = time.time()
def pr(ax, predictions, labels, title='Precision-Recall curve'):
    ''' outputs the roc curve on ax axes'''
    prediction_prob = predictions.toPandas()['probability'].apply(lambda x:x[1]).values
    pr, rc, _ = precision_recall_curve(labels, prediction_prob)
    ax.plot(pr, rc)
    ax.set_facecolor('xkcd:wheat')
    ax.set_xlabel('Recall Rate')
    ax.set_ylabel('Precision Rate')
    ax.set_title(title)
   
plt.clf()

labels=predictions.toPandas()['label']
fig = plt.figure()
ax = fig.add_subplot(111)
pr(ax, predictions,labels)
# %matplot plt


end = time.time()
c4t12_print(start, end)
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# 4 Core and 12 Tasks take 141.40236735343933 seconds in thi model

# %%
# Gradient Boosted Tree Classifier seems to be the winner model, let us plot its ROC Curve
 
start = time.time()
def roc(ax, predictions, labels, title='ROC curve'):
    ''' outputs the roc curve on ax axes'''
    prediction_prob = predictions.toPandas()['probability'].apply(lambda x:x[1]).values
    fpr, tpr, _ = roc_curve(labels, prediction_prob)
    ax.plot(fpr, tpr)
    ax.set_facecolor('xkcd:wheat')
    ax.set_xlabel('False Positive Rate')
    ax.set_ylabel('True Positive Rate')
    ax.set_title(title)
   

plt.clf()

labels=predictions.toPandas()['label']
fig = plt.figure()
ax = fig.add_subplot(111)
roc(ax, predictions,labels)
#plt.save_fig('lr_roc.png')
# %matplot plt
end = time.time()
c4t12_print(start, end)
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# 4 Core and 12 Tasks take 13.51010251045227 seconds in thi model

# %% [markdown]
# question:
#
# - 1.what's optimal combination of manager, core and task node. Accoridng to some AWS slide, they provide core:task propotion as 1:5
# - 2.All task node is not working when i use EMR. They all idle statu during this caculation period.
# - 3.For now i only use m5.xlarge as my EBS on aws. After some research, i believe c5.xlarge or c5.4xlarge will more fit EMR calcuation way. But when i try to use c5, it will give some s3 or ec2 permission error
# - 4.According to AWS documents, the maxizme virul CPU in one EMR, for instance, m5.xlarge have 4 vCPU, so we can add 64 m5.xlarge in one EMR 256
# - 5.Can i still use AWS educate to do more explore?

# %% [markdown]
# # <a id="7.Main_Function">7.Main Function</a>
# <a href="#1.Summary">Click this Link back to Top</a>

# %%
class_import = ImportData()
df_1 = class_import.import_data()
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# Current, We use 1 Master, 2 Cores, and 2 Tasks spend 9.699035406112671 time

# %%
# def main():
#     """
#     We use this function to call process one by one.
#     """


#     # ***********************import******************************
#     class_import = ImportData()
#     df_1 = class_import.import_data()

    
#     return df_1



# if __name__=="__main__":
#     """:arg
    
#     """
#     df_1 = main()

#     print("OVER")
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %% [markdown]
# # <a id="8.Test_Code">8.Test Code</a>
# <a href="#1.Summary">Click this Link back to Top</a>

# %%
spark = SparkSession \
        .builder \
        .master("local") \
        .appName("Sparkify_ML") \
        .getOrCreate()
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# name 'SparkSession' is not defined
# Traceback (most recent call last):
# NameError: name 'SparkSession' is not defined

# %%
def c4t12_print(start, end):
    return print('4 Core and 0 Tasks take {} seconds in thi model'.format(end - start))
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %% [markdown]
# """
# start = time.time()
# df = pd.read_json(datapath_sparkify)
# end = time.time()
# print("Pandas load 12 GB files use", end-start)
# """

# %%
datapath_sparkify = 's3://03-test-bucket/medium-sparkify-event-data.json'
data_min = ''
start = time.time()
df = spark.read.json(datapath_sparkify)
end = time.time()
print("4 Core and 12 Task with Spark load 12 GB files use", end-start)
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# 4 Core and 12 Task with Spark load 12 GB files use 12.8877854347229
