# %%
# %reload_ext sql
#%sql postgresql://postgres:00wasabi00@127.0.0.1/salesdb
# %sql postgresql://postgres:00wasabi00@127.0.0.1/banking_tables
# Out:
# 'Connected: postgres@banking_tables'

# %% [markdown]
# If table is telling only one things, which means all other varibales is describing the primary key, this is a good table

# %% [markdown]
# Good Table:
# 1.table about 1 thing at once(eg, customer)
# 2.key(unique but can have lots columns to construct) + "rest"
# key =ID     "rest"=info/description (describe the entrie of the key, not only one columns of key)

# %% [markdown]
# In sales table, Tax will describe 'state', although it associate sales but it for state

# %% [markdown]
# Functional is dependacy

# %% [markdown]
# Loan_and_br is a good table, because these two table tell one thing about LOAN.
#
# Loan_and_br is all concern about LOAN_NUMBER

# %% [markdown]
# In a table
# C1 -----Functional determines ----> C4
# C4 <----Functional dependends-----C1
# State---Functional determines---->Tax
# Tax <----Functional dependends-----State
# when i know 'State' is, i will know 'Tax'
# When i know primary key(CWID), i konw all other column(all schema in this table)

# %% [markdown]
# 3NF/ BCNF are rules for test good/bad tables

# %% [markdown]
# Tell me three addtion axion
# - 1.name
# - 2.defination,a->b ^ a->r => a->br
# - 3.prof, using Armston's axiom

# %%
result=a;                                          #reflexivity
while (changes to result) do
    for each B->r in F do
        begin
            if B<=result then result=result U Y      #transitiviey
        end

# %% [markdown]
# For homework, first think of order

# %%
from IPython.display import Image
Image("02_data/Banking_tables.png")

# %% [markdown]
# Find the names of all branches that have assets greater than those of at least one branch located in Broooklyn

# %%
# %%sql
# select a.branch_name
# from branch as a, branch as b
# where a.assets>b.assets
# and b.branch_city='Brooklyn'
# Out:
#  * postgresql://postgres:***@127.0.0.1/banking_tables
#    postgresql://postgres:***@127.0.0.1/salesdb
# 2 rows affected.
# [('Downtown  ',), ('Round Hill',)]

# %% [markdown]
# /*
# - cover: ch 1-7 except 5
# - study :slides ,HM1 HM2 (mid, cross 75% of a overall sales,etc
# - questions:
# 1.english->sql->Realtional Aregbarl
# 2.exquiv of 2 RA exps(eg, R1 naturla join R2== R1 natural join R2)
# 3.sql quries from HM 1 and HM2
# 4.CH4 (exercies questions) defining types, domains, creating tables (Schama's)
# 5.know: closues of attribute sets, FD's , BCNF, 3NF, LLJD, Dap presttioin
# 6.Three addtional axioms ( Name / Definication / proof ( based on Armstrongs Axioms)
