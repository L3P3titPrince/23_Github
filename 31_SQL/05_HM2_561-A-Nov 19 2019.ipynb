# %%
# %load_ext sql
# %sql postgresql://postgres:00wasabi00@127.0.0.1/salesdb
# Out:
# 'Connected: postgres@salesdb'

# %% [markdown]
# # CS561 – Programming Assignment 2

# %% [markdown]
# 1.For each customer, product and state combination, compute
# - (1) the customer's average sale of this product for the state,
# - (2) the average sale of the product and the customer but for the other states and
# - (3) the customer’s average sale for the given state, but for the other products.

# %%
# %%sql
# with avg_table as(
#     select cust, prod, state,round(avg(quant),2) as cust_avg
#     from sales
#     group by cust, prod, state
# ),
# avg_state as(
#     select a.cust,a.prod,a.state, avg(b.quant) as other_state_avg
#     from sales as a
#     join sales as b
#     on a.cust=b.cust
#     and a.prod=b.prod
#     and a.state != b.state
#     group by a.cust,a.prod,a.state
# ),
# avg_prod as(
#     select a.cust,a.prod,a.state, avg(b.quant) as other_prod_avg
#     from sales as a
#     join sales as b
#     on a.cust=b.cust
#     and a.prod<>b.prod
#     and a.state=b.state
#     group by a.cust,a.prod,a.state
# )
# select distinct a.cust,a.prod,a.state,
# round(a.cust_avg,2) as cust_avg,
# round(b.other_state_avg,2) as other_state_avg,
# round(c.other_prod_avg,2) as other_prod_avg
# from avg_table as a
# natural inner join avg_state as b
# natural inner join avg_prod as c
# order by a.cust,a.prod
# Out:
#  * postgresql://postgres:***@127.0.0.1/salesdb
# 187 rows affected.
# [('Bloom', 'Bread', 'CT', Decimal('1529.60'), Decimal('2527.86'), Decimal('2782.43')),
#  ('Bloom', 'Bread', 'NJ', Decimal('2160.60'), Decimal('2077.14'), Decimal('2567.17')),
#  ('Bloom', 'Bread', 'NY', Decimal('3792.00'), Decimal('1959.18'), Decimal('2546.35')),
#  ('Bloom', 'Bread', 'PA', Decimal('3100.00'), Decimal('2022.09'), Decimal('2146.41')),
#  ('Bloom', 'Butter', 'CT', Decimal('4279.00'), Decimal('2386.00'), Decimal('2472.00')),
#  ('Bloom', 'Butter', 'NJ', Decimal('3718.00'), Decimal('2666.50'), Decimal('2453.46')),
#  ('Bloom', 'Butter', 'NY', Decimal('1054.00'), Decimal('3998.50'), Decimal('2707.41')),
#  ('Bloom', 'Coke', 'CT', Decimal('2284.00'), Decimal('2354.57'), Decimal('2562.96')),
#  ('Bloom', 'Coke', 'NJ', Decimal('2017.00'), Decimal('2499.83'), Decimal('2552.46')),
#  ('Bloom', 'Coke', 'NY', Decimal('1229.00'), Decimal('2477.63'), Decimal('2697.12')),
# ...

# %% [markdown]
# <br>

# %% [markdown]
# 2.For customer and product, show the average sales before and after each quarter (e.g., for Q2, show average sales of Q1 and Q3. For “before” Q1 and “after” Q4, display <NULL>. The “YEAR” attribute is not considered for this query – for example, both Q1 of 2007 and Q1 of 2008 are considered Q1 regardless of the year.

# %%
# %%sql
# With
# t_all_month AS(
# SELECT DISTINCT s1.prod, s1.cust,
# case when s2.month in (1,2,3) then 1
#      when s2.month in (4,5,6) then 2
#      when s2.month in (7,8,9) then 3
#      when s2.month in (10,11,12) then 4 END AS Q
# FROM sales s1, sales s2
# -- ORDER BY 1,2,3
# ),
#
#
# t1 AS (
# SELECT prod, cust, ROUND(AVG(quant)) AS avq,
# case when month in (1,2,3) then 1
#      when month in (4,5,6) then 2
#      when month in (7,8,9) then 3
#      when month in (10,11,12) then 4 END AS Q
# FROM sales
# GROUP BY prod, cust, Q
# ),
#
#
# tbf AS(
# SELECT t1.prod, t1.cust, bf.Q, bf.avq as bfq
# FROM t1
# LEFT JOIN t1 bf ON t1.cust = bf.cust AND t1.prod = bf.prod AND t1.Q-1 = bf.Q
# -- WHERE t1.prod='Bread' and t1.cust='Bloom'
# ),
#
#
# taf AS
# (
# SELECT t1.prod, t1.cust, af.Q, af.avq as afq
# FROM t1
# LEFT JOIN t1 af ON t1.cust = af.cust AND t1.prod = af.prod AND t1.Q+1 = af.Q
# -- WHERE t1.prod='Bread' and t1.cust='Bloom'
# )
#
#
#
#
# SELECT ta.prod,  ta.cust,  ta.Q,
# -- t1.avq, -- USED for checking
# bfq as BEFORE_AVG, afq as AFTER_AVG
# FROM t_all_month ta
# LEFT JOIN t1 on ta.prod = t1.prod AND ta.cust = t1.cust AND ta.Q = t1.Q  -- keep 200 rows, this is neccessary
# LEFT JOIN tbf ON t1.Q = tbf.Q+1 AND t1.cust = tbf.cust AND t1.prod = tbf.prod  -- NEED to add back month difference
# LEFT JOIN taf ON t1.Q = taf.Q-1 AND t1.cust = taf.cust AND t1.prod = taf.prod
# -- WHERE t1.prod='Bread' and t1.cust='Bloom'
# ORDER BY 1,2,3
# Out:
#  * postgresql://postgres:***@127.0.0.1/salesdb
# 200 rows affected.
# [('Bread', 'Bloom', 1, None, Decimal('539')),
#  ('Bread', 'Bloom', 2, Decimal('3267'), Decimal('2388')),
#  ('Bread', 'Bloom', 3, Decimal('539'), Decimal('1106')),
#  ('Bread', 'Bloom', 4, Decimal('2388'), None),
#  ('Bread', 'Emily', 1, None, Decimal('1720')),
#  ('Bread', 'Emily', 2, Decimal('492'), Decimal('807')),
#  ('Bread', 'Emily', 3, Decimal('1720'), Decimal('2318')),
#  ('Bread', 'Emily', 4, Decimal('807'), None),
#  ('Bread', 'Helen', 1, None, Decimal('2648')),
#  ('Bread', 'Helen', 2, Decimal('3530'), None),
#  ('Bread', 'Helen', 3, None, None),
#  ('Bread', 'Helen', 4, None, None),
#  ('Bread', 'Knuth', 1, None, Decimal('3283')),
#  ('Bread', 'Knuth', 2, Decimal('3366'), Decimal('1579')),
#  ('Bread', 'Knuth', 3, Decimal('3283'), Decimal('1405')),
#  ('Bread', 'Knuth', 4, Decimal('1579'), None),
#  ('Bread', 'Sam', 1, None, Decimal('2735')),
#  ('Bread', 'Sam', 2, Decimal('1378'), Decimal('1622')),
# ...

# %% [markdown]
# <br>

# %% [markdown]
# <br>

# %% [markdown]
# 3.For each product, find the median sales quantity (assume an odd number of sales for simplicity of presentation). (NOTE – “median” is defined as “denoting or relating to a value or quantity lying at the midpoint of a frequency distribution of observed values or quantities, such that there is an equal probability of falling above or below it.” E.g., Median value of the list {13, 23, 12, 16, 15, 9, 29} is 15.

# %%
# %%sql
# SELECT
#     prod,
#     percentile_disc(0.5) WITHIN GROUP (ORDER BY quant) AS median_quant
# FROM sales
# GROUP BY prod
# ORDER BY prod
# Out:
#  * postgresql://postgres:***@127.0.0.1/salesdb
# 10 rows affected.
# [('Bread', 1932),
#  ('Butter', 1715),
#  ('Coke', 2681),
#  ('Cookies', 2500),
#  ('Eggs', 2151),
#  ('Fruits', 2525),
#  ('Milk', 1839),
#  ('Pepsi', 2591),
#  ('Soap', 2231),
#  ('Yogurt', 2336)]

# %% [markdown]
# <br>

# %% [markdown]
# <br>

# %% [markdown]
# 4.For customer and product, find the month by which time, 2/3 of the sales quantities have been purchased. Again, for this query, the “YEAR” attribute is not considered. Another way to view this query is to pretend all 500 rows of sales data are from the same year.

# %%
# %%sql
# with t1 as (
#     select cust,prod,month,sum(quant)
#     from sales
#     group by cust, prod,month
#     order by cust, prod,month asc
# ),
# t2 as (
#     select b.cust, b.prod, b.month, sum(a.sum) as add_quant
#     from t1 as a, t1 as b
#     where a.cust=b.cust
#     and a.prod=b.prod
#     and a.month<=b.month
#     group by b.cust, b.prod, b.month
#     order by b.cust, b.prod, b.month
# ),
# t3 as (
#     select cust, prod, max(add_quant)*2/3 as the_two_third_amount
#     from t2
#     group by cust, prod
#     order by cust, prod
# )
# select a.cust, a.prod,min(b.month) as two_third_purchased_by_month
# from t2 as b,t3 as a
# where a.cust=b.cust
# and a.prod=b.prod
# and add_quant>=the_two_third_amount
# group by a.cust, a.prod
# order by a.cust, a.prod
# Out:
#  * postgresql://postgres:***@127.0.0.1/salesdb
# 50 rows affected.
# [('Bloom', 'Bread', 8),
#  ('Bloom', 'Butter', 10),
#  ('Bloom', 'Coke', 7),
#  ('Bloom', 'Cookies', 9),
#  ('Bloom', 'Eggs', 5),
#  ('Bloom', 'Fruits', 7),
#  ('Bloom', 'Milk', 10),
#  ('Bloom', 'Pepsi', 11),
#  ('Bloom', 'Soap', 7),
#  ('Bloom', 'Yogurt', 9),
#  ('Emily', 'Bread', 9),
#  ('Emily', 'Butter', 7),
#  ('Emily', 'Coke', 6),
#  ('Emily', 'Cookies', 11),
#  ('Emily', 'Eggs', 9),
#  ('Emily', 'Fruits', 8),
#  ('Emily', 'Milk', 9),
#  ('Emily', 'Pepsi', 5),
#  ('Emily', 'Soap', 10),
#  ('Emily', 'Yogurt', 6),
#  ('Helen', 'Bread', 6),
#  ('Helen', 'Butter', 7),
#  ('Helen', 'Coke', 10),
#  ('Helen', 'Cookies', 8),
#  ('Helen', 'Eggs', 10),
#  ('Helen', 'Fruits', 6),
#  ('Helen', 'Milk', 4),
#  ('Helen', 'Pepsi', 9),
#  ('Helen', 'Soap', 8),
#  ('Helen', 'Yogurt', 8),
#  ('Knuth', 'Bread', 5),
#  ('Knuth', 'Butter', 10),
#  ('Knuth', 'Coke', 6),
#  ('Knuth', 'Cookies', 7),
#  ('Knuth', 'Eggs', 11),
# ...

# %%
select *
from sales

# %%
with q1 as(
    select b.cust,b.prod,b.month,round(avg(b.quant),2)
    from (select cust,prod,month from sales where sales.month in(1,2,3)) as a
    left join sales as b
    on a.cust=b.cust
    and a.month <> b.month
    group by b.cust,b.prod,b.month
),

# %%
# %%sql
# select cust,prod,state,quant
# from sales
# where cust='Bloom'
# and prod='Pepsi'
# and state='NY'

# %%
# %%sql
# select cust, prod, state,round(avg(quant),2) as "AVG_Q"
# from sales
# group by cust, prod, state

# %%
# %%sql
# with avg_all as(
#     select cust, prod, state,round(avg(quant),2) as avg_q
#     from sales
#     group by cust, prod, state
# ),
# avg_no_PA as(
#     select cust, prod, state,round(avg(quant),2) as avg_q
#     from sales
#     group by cust, prod, state
#     having state!='PA'
# ),
# avg_no_NJ as(
#     select cust, prod, state,round(avg(quant),2) as avg_q
#     from sales
#     group by cust, prod, state
#     having state!='NJ'
# ),
# avg_no_CT as(
#     select cust, prod, state,round(avg(quant),2) as avg_q
#     from sales
#     group by cust, prod, state
#     having state!='CT'
# ),
# avg_no_NY as(
#     select cust, prod, state,round(avg(quant),2) as avg_q
#     from sales
#     group by cust, prod, state
#     having state!='NY'
# ),
# avg_other as(
# select avg_all.cust,
# from avg_all
# inner join avg_no_PA on avg_all.cust=avg_no_PA.cust and avg_all.prod=avg_no_PA.prod
# )

# %% [markdown]
# how many rows equla or less than me   #caculate mid

# %%
# %%sql
# SELECT
#     prod,
#     percentile_cont(0.1) WITHIN GROUP (ORDER BY quant) As cont_median,
#     /*
#     percentile_disc(0.5) WITHIN GROUP (ORDER BY score) AS disc_median,
#     mode() WITHIN GROUP (ORDER BY score) AS mode,
#     */
#     COUNT(*) As num_scores
# FROM sales
# GROUP BY prod
# ORDER BY prod
# Out:
#  * postgresql://postgres:***@127.0.0.1/salesdb
# 10 rows affected.
# [('Bread', 256.0, 51),
#  ('Butter', 453.0, 48),
#  ('Coke', 755.0, 51),
#  ('Cookies', 590.0, 47),
#  ('Eggs', 804.6, 49),
#  ('Fruits', 467.6, 63),
#  ('Milk', 300.9, 50),
#  ('Pepsi', 572.5, 54),
#  ('Soap', 413.8, 45),
#  ('Yogurt', 735.3, 42)]

# %%
select prod,count(prod)
from sales
# Out:
#  * postgresql://postgres:***@127.0.0.1/salesdb
# (psycopg2.errors.GroupingError) column "sales.prod" must appear in the GROUP BY clause or be used in an aggregate function
# LINE 1: select prod,count(prod)
#                ^
#
# [SQL: select prod,count(prod)
# from sales]
# (Background on this error at: http://sqlalche.me/e/f405)

# %%
# %%sql
# with t1 as(
#     select prod,count(prod)/2
#     from sales
#     group by prod
# )
# select *
# from sales
# order by prod asc,quant asc
# Out:
#  * postgresql://postgres:***@127.0.0.1/salesdb
# 500 rows affected.
# [('Emily', 'Bread', 28, 9, 2005, 'PA', 42),
#  ('Sam', 'Bread', 13, 11, 2008, 'PA', 93),
#  ('Emily', 'Bread', 21, 6, 2000, 'NJ', 141),
#  ('Sam', 'Bread', 22, 7, 2006, 'CT', 207),
#  ('Emily', 'Bread', 13, 5, 2001, 'NJ', 232),
#  ('Bloom', 'Bread', 13, 6, 2000, 'CT', 256),
#  ('Helen', 'Bread', 21, 5, 2000, 'NY', 389),
#  ('Bloom', 'Bread', 20, 4, 2006, 'CT', 417),
#  ('Emily', 'Bread', 21, 3, 2001, 'NY', 492),
#  ('Sam', 'Bread', 7, 7, 2007, 'PA', 872),
#  ('Bloom', 'Bread', 22, 6, 2008, 'NJ', 944),
#  ('Knuth', 'Bread', 2, 11, 2002, 'NJ', 1013),
#  ('Knuth', 'Bread', 16, 8, 2004, 'CT', 1095),
#  ('Bloom', 'Bread', 3, 12, 2008, 'NJ', 1106),
#  ('Sam', 'Bread', 18, 1, 2002, 'NJ', 1378),
#  ('Helen', 'Bread', 26, 5, 2006, 'CT', 1406),
#  ('Bloom', 'Bread', 4, 7, 2006, 'CT', 1494),
#  ('Emily', 'Bread', 4, 9, 2000, 'PA', 1572),
#  ('Sam', 'Bread', 29, 8, 2000, 'CT', 1599),
# ...

# %%
SELECT
    prod,
    percentile_cont(0.1) WITHIN GROUP (ORDER BY quant) As cont_median,
    /*
    percentile_disc(0.5) WITHIN GROUP (ORDER BY score) AS disc_median,
    mode() WITHIN GROUP (ORDER BY score) AS mode,
    */
    COUNT(*) As num_scores
FROM sales
GROUP BY prod
ORDER BY prod

# %%
# %%sql
# select *
#     from sales
#     order by cust, prod,month asc
# Out:
#  * postgresql://postgres:***@127.0.0.1/salesdb
# 500 rows affected.
# [('Bloom', 'Bread', 22, 1, 2003, 'CT', 2220),
#  ('Bloom', 'Bread', 25, 2, 2000, 'NJ', 4778),
#  ('Bloom', 'Bread', 13, 3, 2006, 'NY', 3792),
#  ('Bloom', 'Bread', 5, 3, 2007, 'NJ', 2277),
#  ('Bloom', 'Bread', 20, 4, 2006, 'CT', 417),
#  ('Bloom', 'Bread', 13, 6, 2000, 'CT', 256),
#  ('Bloom', 'Bread', 22, 6, 2008, 'NJ', 944),
#  ('Bloom', 'Bread', 4, 7, 2006, 'CT', 1494),
#  ('Bloom', 'Bread', 25, 8, 2004, 'PA', 3100),
#  ('Bloom', 'Bread', 14, 9, 2007, 'CT', 3261),
#  ('Bloom', 'Bread', 4, 9, 2008, 'NJ', 1698),
#  ('Bloom', 'Bread', 3, 12, 2008, 'NJ', 1106),
#  ('Bloom', 'Butter', 16, 8, 2003, 'NY', 1054),
#  ('Bloom', 'Butter', 17, 9, 2008, 'NJ', 3718),
#  ('Bloom', 'Butter', 9, 10, 2000, 'CT', 4279),
#  ('Bloom', 'Coke', 14, 1, 2008, 'CT', 928),
#  ('Bloom', 'Coke', 7, 2, 2000, 'NY', 1229),
#  ('Bloom', 'Coke', 5, 4, 2003, 'PA', 2681),
#  ('Bloom', 'Coke', 22, 7, 2008, 'CT', 3640),
# ...

# %%
# %%sql
# with t1 as(
#     select *
#     from sales
#     order by cust, prod,quant asc
# )
#     select cust,prod,sum(quant)*0.6666667 as two_three_prod
#     from t1
#     group by cust,prod
#     order by cust, prod
# Out:
#  * postgresql://postgres:***@127.0.0.1/salesdb
# 50 rows affected.
# [('Bloom', 'Bread', Decimal('16895.3341781')),
#  ('Bloom', 'Butter', Decimal('6034.0003017')),
#  ('Bloom', 'Coke', Decimal('14033.3340350')),
#  ('Bloom', 'Cookies', Decimal('18414.6675874')),
#  ('Bloom', 'Eggs', Decimal('18368.6675851')),
#  ('Bloom', 'Fruits', Decimal('28007.3347337')),
#  ('Bloom', 'Milk', Decimal('23960.6678647')),
#  ('Bloom', 'Pepsi', Decimal('10260.0005130')),
#  ('Bloom', 'Soap', Decimal('9509.3338088')),
#  ('Bloom', 'Yogurt', Decimal('11780.0005890')),
#  ('Emily', 'Bread', Decimal('10228.6671781')),
#  ('Emily', 'Butter', Decimal('13901.3340284')),
#  ('Emily', 'Coke', Decimal('14454.0007227')),
#  ('Emily', 'Cookies', Decimal('28510.0014255')),
#  ('Emily', 'Eggs', Decimal('22053.3344360')),
#  ('Emily', 'Fruits', Decimal('23372.6678353')),
#  ('Emily', 'Milk', Decimal('14204.6673769')),
#  ('Emily', 'Pepsi', Decimal('15188.0007594')),
#  ('Emily', 'Soap', Decimal('12860.0006430')),
# ...

# %%
# %%sql
# with t1 as(
#     select *
#     from sales
#     order by cust, prod,quant asc
# )
# select month, (
#     select sum(acc) from t1 as b where b.quant<= a.quant) as acc
# from t1 as a
# group by id;
# Out:
#  * postgresql://postgres:***@127.0.0.1/salesdb
# (psycopg2.errors.UndefinedColumn) column "acc" does not exist
# LINE 7:     select sum(acc) from t1 as b where b.quant<= a.quant) as...
#                        ^
#
# [SQL: with t1 as(
#     select *
#     from sales
#     order by cust, prod,quant asc
# )
# select month, (
#     select sum(acc) from t1 as b where b.quant<= a.quant) as acc
# from t1 as a
# group by id;]
# (Background on this error at: http://sqlalche.me/e/f405)

# %%
# %%sql
# with t1 as(
#     select *
#     from sales
#     order by cust, prod,quant asc
# )
# select b.cust, b.prod, b.quant,b.month, sum(a.quant)
# from t1 as a,t1 as b
# where a.month<=b.month
# group by b.cust, b.prod,b.quant,b.month
# order by b.cust,b.prod,b.month
# Out:
#  * postgresql://postgres:***@127.0.0.1/salesdb
# 500 rows affected.
# [('Bloom', 'Bread', 2220, 1, 126442),
#  ('Bloom', 'Bread', 4778, 2, 234423),
#  ('Bloom', 'Bread', 3792, 3, 302436),
#  ('Bloom', 'Bread', 2277, 3, 302436),
#  ('Bloom', 'Bread', 417, 4, 411220),
#  ('Bloom', 'Bread', 944, 6, 602411),
#  ('Bloom', 'Bread', 256, 6, 602411),
#  ('Bloom', 'Bread', 1494, 7, 707536),
#  ('Bloom', 'Bread', 3100, 8, 781080),
#  ('Bloom', 'Bread', 3261, 9, 885213),
#  ('Bloom', 'Bread', 1698, 9, 885213),
#  ('Bloom', 'Bread', 1106, 12, 1194294),
#  ('Bloom', 'Butter', 1054, 8, 781080),
#  ('Bloom', 'Butter', 3718, 9, 885213),
#  ('Bloom', 'Butter', 4279, 10, 996557),
#  ('Bloom', 'Coke', 928, 1, 126442),
#  ('Bloom', 'Coke', 1229, 2, 234423),
#  ('Bloom', 'Coke', 2681, 4, 411220),
#  ('Bloom', 'Coke', 3058, 7, 707536),
#  ('Bloom', 'Coke', 3640, 7, 707536),
#  ('Bloom', 'Coke', 3654, 7, 707536),
#  ('Bloom', 'Coke', 279, 8, 781080),
#  ('Bloom', 'Coke', 2714, 9, 885213),
# ...

# %%
# %%sql
# with t1 as (
#     select *
#     from sales
#     order by cust, prod,quant asc
# ),
# t2 as (
#     select cust,prod,sum(quant)*2/3 as two_three_prod
#     from t1
#     group by cust,prod
# ),
# t3 as (
#     select distinct t1.cust,t1.prod,t1.month,
#     case
#     when t1.quant> t2.two_three_prod then t1.month
#     else 222 end
#     from t1
#     left join t2 using(cust,prod)
#     order by t1.cust, t1.prod
#
# )
# select *
# from t3

# %%
# %%sql
# With
# t_all_month AS(
# SELECT DISTINCT s1.prod, s1.cust,
# case when s2.month in (1,2,3) then 1
#      when s2.month in (4,5,6) then 2
#      when s2.month in (7,8,9) then 3
#      when s2.month in (10,11,12) then 4 END AS Q
# FROM sales s1, sales s2
# -- ORDER BY 1,2,3
# ),
#
#
# t1 AS (
# SELECT prod, cust, ROUND(AVG(quant)) AS avq,
# case when month in (1,2,3) then 1
#      when month in (4,5,6) then 2
#      when month in (7,8,9) then 3
#      when month in (10,11,12) then 4 END AS Q
# FROM sales
# GROUP BY prod, cust, Q
# ),
#
#
# tbf AS(
# SELECT t1.prod, t1.cust, bf.Q, bf.avq as bfq
# FROM t1
# LEFT JOIN t1 bf ON t1.cust = bf.cust AND t1.prod = bf.prod AND t1.Q-1 = bf.Q
# -- WHERE t1.prod='Bread' and t1.cust='Bloom'
# ),
#
#
# taf AS
# (
# SELECT t1.prod, t1.cust, af.Q, af.avq as afq
# FROM t1
# LEFT JOIN t1 af ON t1.cust = af.cust AND t1.prod = af.prod AND t1.Q+1 = af.Q
# -- WHERE t1.prod='Bread' and t1.cust='Bloom'
# )
#
#
#
#
# SELECT ta.prod,  ta.cust,  ta.Q,
# -- t1.avq, -- USED for checking
# bfq as BEFORE_AVG, afq as AFTER_AVG
# FROM t_all_month ta
# LEFT JOIN t1 on ta.prod = t1.prod AND ta.cust = t1.cust AND ta.Q = t1.Q  -- keep 200 rows, this is neccessary
# LEFT JOIN tbf ON t1.Q = tbf.Q+1 AND t1.cust = tbf.cust AND t1.prod = tbf.prod  -- NEED to add back month difference
# LEFT JOIN taf ON t1.Q = taf.Q-1 AND t1.cust = taf.cust AND t1.prod = taf.prod
# -- WHERE t1.prod='Bread' and t1.cust='Bloom'
# ORDER BY 1,2,3
# Out:
#  * postgresql://postgres:***@127.0.0.1/salesdb
# 200 rows affected.
# [('Bread', 'Bloom', 1, None, Decimal('539')),
#  ('Bread', 'Bloom', 2, Decimal('3267'), Decimal('2388')),
#  ('Bread', 'Bloom', 3, Decimal('539'), Decimal('1106')),
#  ('Bread', 'Bloom', 4, Decimal('2388'), None),
#  ('Bread', 'Emily', 1, None, Decimal('1720')),
#  ('Bread', 'Emily', 2, Decimal('492'), Decimal('807')),
#  ('Bread', 'Emily', 3, Decimal('1720'), Decimal('2318')),
#  ('Bread', 'Emily', 4, Decimal('807'), None),
#  ('Bread', 'Helen', 1, None, Decimal('2648')),
#  ('Bread', 'Helen', 2, Decimal('3530'), None),
#  ('Bread', 'Helen', 3, None, None),
#  ('Bread', 'Helen', 4, None, None),
#  ('Bread', 'Knuth', 1, None, Decimal('3283')),
#  ('Bread', 'Knuth', 2, Decimal('3366'), Decimal('1579')),
#  ('Bread', 'Knuth', 3, Decimal('3283'), Decimal('1405')),
#  ('Bread', 'Knuth', 4, Decimal('1579'), None),
#  ('Bread', 'Sam', 1, None, Decimal('2735')),
#  ('Bread', 'Sam', 2, Decimal('1378'), Decimal('1622')),
# ...

# %%
# Out:
#  * postgresql://postgres:***@127.0.0.1/salesdb
# 335 rows affected.
# [('Bloom', 'Bread', 1, 222),
#  ('Bloom', 'Bread', 2, 222),
#  ('Bloom', 'Bread', 3, 222),
#  ('Bloom', 'Bread', 4, 222),
#  ('Bloom', 'Bread', 6, 222),
#  ('Bloom', 'Bread', 7, 222),
#  ('Bloom', 'Bread', 8, 222),
#  ('Bloom', 'Bread', 9, 222),
#  ('Bloom', 'Bread', 12, 222),
#  ('Bloom', 'Butter', 8, 222),
#  ('Bloom', 'Butter', 9, 222),
#  ('Bloom', 'Butter', 10, 222),
#  ('Bloom', 'Coke', 1, 222),
#  ('Bloom', 'Coke', 2, 222),
#  ('Bloom', 'Coke', 4, 222),
#  ('Bloom', 'Coke', 7, 222),
#  ('Bloom', 'Coke', 8, 222),
#  ('Bloom', 'Coke', 9, 222),
#  ('Bloom', 'Coke', 10, 222),
#  ('Bloom', 'Cookies', 6, 222),
#  ('Bloom', 'Cookies', 7, 222),
#  ('Bloom', 'Cookies', 9, 222),
#  ('Bloom', 'Cookies', 10, 222),
#  ('Bloom', 'Cookies', 11, 222),
#  ('Bloom', 'Eggs', 1, 222),
#  ('Bloom', 'Eggs', 4, 222),
#  ('Bloom', 'Eggs', 5, 222),
#  ('Bloom', 'Eggs', 7, 222),
#  ('Bloom', 'Eggs', 9, 222),
# ...

# %%
# %%sql
# With t1 AS (
# SELECT cust, prod, state, round(avg(quant)) AS CUST_AVG
# FROM sales
# GROUP BY 1,2,3),
#
# t2 AS (
# SELECT s1.cust, s1.prod, s1.state, round(avg(s2.quant)) AS OTHER_STATE_AVG
# FROM sales s1, sales s2
# WHERE s1.cust = s2.cust AND s1.prod = s2.prod AND s1.state != s2.state
# GROUP BY 1,2,3),
#
# t3 AS (
# SELECT s1.cust, s1.prod, s1.state, round(avg(s2.quant)) AS OTHER_PROD_AVG
# FROM sales s1, sales s2
# WHERE s1.cust = s2.cust AND s1.prod != s2.prod AND s1.state = s2.state
# GROUP BY 1,2,3)
#
# SELECT *
# FROM t1
# NATURAL INNER JOIN t2
# NATURAL INNER JOIN t3
# order by cust,prod
# Out:
#  * postgresql://postgres:***@127.0.0.1/salesdb
# 187 rows affected.
# [('Bloom', 'Bread', 'CT', Decimal('1530'), Decimal('2528'), Decimal('2782')),
#  ('Bloom', 'Bread', 'NY', Decimal('3792'), Decimal('1959'), Decimal('2546')),
#  ('Bloom', 'Bread', 'PA', Decimal('3100'), Decimal('2022'), Decimal('2146')),
#  ('Bloom', 'Bread', 'NJ', Decimal('2161'), Decimal('2077'), Decimal('2567')),
#  ('Bloom', 'Butter', 'NY', Decimal('1054'), Decimal('3999'), Decimal('2707')),
#  ('Bloom', 'Butter', 'NJ', Decimal('3718'), Decimal('2667'), Decimal('2453')),
#  ('Bloom', 'Butter', 'CT', Decimal('4279'), Decimal('2386'), Decimal('2472')),
#  ('Bloom', 'Coke', 'PA', Decimal('3067'), Decimal('1975'), Decimal('2056')),
#  ('Bloom', 'Coke', 'NY', Decimal('1229'), Decimal('2478'), Decimal('2697')),
#  ('Bloom', 'Coke', 'CT', Decimal('2284'), Decimal('2355'), Decimal('2563')),
#  ('Bloom', 'Coke', 'NJ', Decimal('2017'), Decimal('2500'), Decimal('2552')),
# ...

# %%
# %%sql
# With
# t_all_month AS(
# SELECT DISTINCT s1.prod, s1.cust,
# case when s2.month in (1,2,3) then 1
#      when s2.month in (4,5,6) then 2
#      when s2.month in (7,8,9) then 3
#      when s2.month in (10,11,12) then 4 END AS Q
# FROM sales s1, sales s2
# -- ORDER BY 1,2,3
# ),
#
#
# t1 AS (
# SELECT prod, cust, ROUND(AVG(quant)) AS avq,
# case when month in (1,2,3) then 1
#      when month in (4,5,6) then 2
#      when month in (7,8,9) then 3
#      when month in (10,11,12) then 4 END AS Q
# FROM sales
# GROUP BY prod, cust, Q
# ),
#
#
# tbf AS(
# SELECT t1.prod, t1.cust, bf.Q, bf.avq as bfq
# FROM t1
# LEFT JOIN t1 bf ON t1.cust = bf.cust AND t1.prod = bf.prod AND t1.Q-1 = bf.Q
# -- WHERE t1.prod='Bread' and t1.cust='Bloom'
# ),
#
#
# taf AS
# (
# SELECT t1.prod, t1.cust, af.Q, af.avq as afq
# FROM t1
# LEFT JOIN t1 af ON t1.cust = af.cust AND t1.prod = af.prod AND t1.Q+1 = af.Q
# -- WHERE t1.prod='Bread' and t1.cust='Bloom'
# )
#
#
#
#
# SELECT ta.prod,  ta.cust,  ta.Q,
# -- t1.avq, -- USED for checking
# bfq as BEFORE_AVG, afq as AFTER_AVG
# FROM t_all_month ta
# LEFT JOIN t1 on ta.prod = t1.prod AND ta.cust = t1.cust AND ta.Q = t1.Q  -- keep 200 rows, this is neccessary
# LEFT JOIN tbf ON t1.Q = tbf.Q+1 AND t1.cust = tbf.cust AND t1.prod = tbf.prod  -- NEED to add back month difference
# LEFT JOIN taf ON t1.Q = taf.Q-1 AND t1.cust = taf.cust AND t1.prod = taf.prod
# -- WHERE t1.prod='Bread' and t1.cust='Bloom'
# ORDER BY 1,2,3
# Out:
#  * postgresql://postgres:***@127.0.0.1/salesdb
# 200 rows affected.
# [('Bread', 'Bloom', 1, None, Decimal('539')),
#  ('Bread', 'Bloom', 2, Decimal('3267'), Decimal('2388')),
#  ('Bread', 'Bloom', 3, Decimal('539'), Decimal('1106')),
#  ('Bread', 'Bloom', 4, Decimal('2388'), None),
#  ('Bread', 'Emily', 1, None, Decimal('1720')),
#  ('Bread', 'Emily', 2, Decimal('492'), Decimal('807')),
#  ('Bread', 'Emily', 3, Decimal('1720'), Decimal('2318')),
#  ('Bread', 'Emily', 4, Decimal('807'), None),
#  ('Bread', 'Helen', 1, None, Decimal('2648')),
#  ('Bread', 'Helen', 2, Decimal('3530'), None),
#  ('Bread', 'Helen', 3, None, None),
#  ('Bread', 'Helen', 4, None, None),
#  ('Bread', 'Knuth', 1, None, Decimal('3283')),
#  ('Bread', 'Knuth', 2, Decimal('3366'), Decimal('1579')),
#  ('Bread', 'Knuth', 3, Decimal('3283'), Decimal('1405')),
#  ('Bread', 'Knuth', 4, Decimal('1579'), None),
#  ('Bread', 'Sam', 1, None, Decimal('2735')),
#  ('Bread', 'Sam', 2, Decimal('1378'), Decimal('1622')),
# ...
